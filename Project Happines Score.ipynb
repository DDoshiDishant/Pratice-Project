# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# NO Null data present in this dataset

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Univariate Analysis

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Region'])
plt.title('Count of Region')
plt.tight_layout()

# %% [markdown]
# This Chart we can seethat Sub Saharan Africa Region Having highest country and North America having lowest Countries.

# %%
sns.violinplot(x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [markdown]
# Most of the country having score is in range 4-7

# %%
sns.violinplot(x='Dystopia Residual',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %% [markdown]
# Dystopia Residual having range between 1.5 to 3.0

# %%
col=['Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']
plt.figure(figsize=(8,10))
for i in range(len(col)):
    sns.distplot(df[col[i]])
    plt.subplot(5,2,i+1)
    plt.tight_layout()
    plt.title('Distribution Chart ')

# %% [markdown]
# Bivariate Analysis

# %%
plt.figure(figsize=(8,10))
for i in range(len(col)):
    sns.scatterplot(df[col[i]],'Happiness Score',data=df)
    plt.subplot(5,2,i+1)
    plt.tight_layout()

# %% [markdown]
# This chare shows as the Economy(GDP per Capita)increaases happiness score Increases

# %%
sns.scatterplot(y='Happiness Rank',x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Happiness Rank'>

# %%
sns.scatterplot(y='Economy (GDP per Capita)',x='Family',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Economy (GDP per Capita)'>

# %% [markdown]
# we cas see the as the Family Increases Economy(GDP per Capita)also increases

# %%
plt.figure(figsize=(20,5))
sns.swarmplot(x='Region',y='Happiness Score',data=df)
plt.tight_layout()
plt.title('Happiness Score Vs Region')
# Out:
# Text(0.5, 1.0, 'Happiness Score Vs Region')

# %% [markdown]
# This Chart Show that Africa Sub saharan Africa has lowest Happiness Score and Western Europe having High Happiness Score

# %%
plt.figure(figsize=(20,5))
sns.stripplot(x='Region',y='Economy (GDP per Capita)',data=df)
plt.tight_layout()
plt.title('Economy (GDP per Capita) Vs Region')
# Out:
# Text(0.5, 1.0, 'Economy (GDP per Capita) Vs Region')

# %% [markdown]
# From this chart we can see that Economy(GDP per capita) is lower in Sub saharan Africa and higher in Middle East and Northen Africa.as well as in western europe

# %%
plt.figure(figsize=(20,5))
sns.stripplot(x='Region',y='Dystopia Residual',data=df)
plt.tight_layout()
plt.title('Dystopia Residual Vs Region')
# Out:
# Text(0.5, 1.0, 'Dystopia Residual Vs Region')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()
df['Country']=lb.fit_transform(df['Country'])
df['Region']=lb.fit_transform(df['Region'])

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %% [markdown]
# # Statastic

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# # OUt Come Of Statastics

# %% [markdown]
# we can see that some features having skewness

# %%
corr=df.corr()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This Relation show that Standard Error having negative relation with Happiness Score

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Checking Outliers

# %%
for i in range(len(col)):
    sns.boxplot(df[col[i]])
    plt.title('i')
    plt.subplot(5,2,i+1)
    plt.show

# %% [markdown]
# This Chart shows Outliers are present in Some Features

# %%
from scipy.stats import zscore

# %%
z=abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (158, 12)
# (149, 12)

# %% [markdown]
# Percentage of loss of data

# %%
pre_loss=(158-149)/158*100
pre_loss
# Out:
# 5.69620253164557

# %%
df_new.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
sd=pd.DataFrame([['Standard Error','1.24','Negative Relation with Target','More']],columns=['Name','Skewness','Corelation','Outliers'])
sd
# Out:
#              Name Skewness                     Corelation Outliers
# 0  Standard Error     1.24  Negative Relation with Target     More

# %% [markdown]
# Standard Error having high skewness as well as negagtive relation with score so we will drop it

# %%
df_new.drop('Standard Error',axis=1,inplace=True)

# %%
df_new.drop('Happiness Rank',axis=1,inplace=True)

# %%
y=df_new['Happiness Score']
y.shape
# Out:
# (149,)

# %%
x=df_new.drop('Happiness Score',axis=1)
x.shape
# Out:
# (149, 9)

# %% [markdown]
# Removing Skewness

# %%
from sklearn.preprocessing import power_transform

# %%
x_new=power_transform(x,method='yeo-johnson')

# %% [markdown]
# Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
X_new=scale.fit_transform(x_new)

# %%
X_new
# Out:
# array([[ 1.19015533,  1.23451354,  1.49245411, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [-0.30048669,  1.23451354,  1.19406711, ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354,  1.26661161, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577, -1.36521585, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966, -1.93874732, ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
x=X_new

# %%
x.shape
# Out:
# (149, 9)

# %% [markdown]
# # Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score
lr=LinearRegression()

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.25)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(lr.score(x_train,y_train)*100,2)==round(lr.score(x_test,y_test)*100,2):
        print("At Random score",i,"Model Performance is very well")
        print("Random stata is:",i)
        print("Train Score",lr.score(x_train,y_train)*100)
        print("Test Score",lr.score(x_test,y_test)*100)
# Out:
# At Random score 20 Model Performance is very well
# Random stata is: 20
# Train Score 99.5325170616394
# Test Score 99.52809174175255
# At Random score 27 Model Performance is very well
# Random stata is: 27
# Train Score 99.5270220816299
# Test Score 99.5315433077106
# At Random score 43 Model Performance is very well
# Random stata is: 43
# Train Score 99.52606544604052
# Test Score 99.5299240459645
# At Random score 143 Model Performance is very well
# Random stata is: 143
# Train Score 99.53359869344152
# Test Score 99.53273332254022
# At Random score 210 Model Performance is very well
# Random stata is: 210
# Train Score 99.53021553685865
# Test Score 99.53366133506488
# At Random score 431 Model Performance is very well
# Random stata is: 431
# Train Score 99.53815136452343
# Test Score 99.54376536561743
# At Random score 452 Model Performance is very well
# Random stata is: 452
# Train Score 99.5354877738817
# Test Score 99.54074751068046
# ...

# %% [markdown]
# from above we get random_state=897 get best result

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=897,test_size=0.25)

# %%
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print('Training Score',lr.score(x_train,y_train))


print('Error')

print('Mean Absolute Error',mean_absolute_error(y_test,pred))
print('Mean Squared Error',mean_squared_error(y_test,pred))
print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Training Score 0.9954066354682042
# Error
# Mean Absolute Error 0.04846341898805192
# Mean Squared Error 0.005602776866767884
# Root Mean Squared Erro 0.07485169915752003

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
dtc=DecisionTreeRegressor()
kn=KNeighborsRegressor(n_neighbors=5)
svm=SVR()
svmp=SVR(kernel='poly')
svml=SVR(kernel='linear')

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Taining Score:-',f.score(x_train,y_train)*100)
    print('Mean Absolute Error',mean_absolute_error(y_test,pred))
    print('Mean Squared Error',mean_squared_error(y_test,pred))
    print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,pred)))

# %%
fun(dtc)
# Out:
# Taining Score:- 100.0
# Mean Absolute Error 0.4525789473684211
# Mean Squared Error 0.29943431578947377
# Root Mean Squared Erro 0.5472059171733012

# %%
fun(kn)
# Out:
# Taining Score:- 93.16188164200703
# Mean Absolute Error 0.3128894736842106
# Mean Squared Error 0.13544623263157893
# Root Mean Squared Erro 0.36803020614017395

# %%
fun(svm)
# Out:
# Taining Score:- 99.2218263848642
# Mean Absolute Error 0.22266086610195615
# Mean Squared Error 0.08012068709817144
# Root Mean Squared Erro 0.2830559787359586

# %%
fun(svmp)
# Out:
# Taining Score:- 96.63569832139439
# Mean Absolute Error 0.24405169963939197
# Mean Squared Error 0.10489920694433474
# Root Mean Squared Erro 0.3238814705171241

# %%
fun(svml)
# Out:
# Taining Score:- 99.4844307916029
# Mean Absolute Error 0.0550446484804946
# Mean Squared Error 0.0054783140028771375
# Root Mean Squared Erro 0.07401563350318051

# %% [markdown]
# # Regurisation

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
ls=Lasso(alpha=0.0001,normalize=False)
rd=Ridge(alpha=0.0001,normalize=False)
es=ElasticNet(alpha=0.0001)

# %%
fun(ls)
# Out:
# Taining Score:- 99.54065899907143
# Mean Absolute Error 0.04845163260496912
# Mean Squared Error 0.005604677049354412
# Root Mean Squared Erro 0.07486439106380557

# %%
fun(rd)
# Out:
# Taining Score:- 99.54066354678727
# Mean Absolute Error 0.048463483319938765
# Mean Squared Error 0.005602782886637905
# Root Mean Squared Erro 0.07485173936948897

# %%
fun(es)
# Out:
# Taining Score:- 99.54066190340541
# Mean Absolute Error 0.04846078405643292
# Mean Squared Error 0.005603262999711659
# Root Mean Squared Erro 0.07485494639442111

# %% [markdown]
# # From the Diffenet models DTC having good Score.

# %% [markdown]
# # Saving Model:-

# %%
import pickle
filename='Happines_Score_Prediction.pkl'
pickle.dump(dtc,open(filename,'wb'))

# %% [markdown]
# # Conclusion:-

# %%
res=pd.DataFrame()
res['Actual']=y_test
res['Predict']=pred

print(res)
sns.lineplot(data=res)
# Out:
#      Actual   Predict
# 29    6.574  6.562955
# 19    6.901  6.884716
# 25    6.750  6.811170
# 140   3.931  3.962290
# 55    5.833  5.821920
# 121   4.512  4.536941
# 30    6.505  6.538145
# 42    6.123  6.073532
# 117   4.550  4.519287
# 22    6.810  6.806593
# 44    5.995  6.076188
# 53    5.855  5.864103
# 48    5.960  5.916086
# 20    6.867  6.805208
# 58    5.813  5.807657
# 102   4.839  4.837069
# 120   4.514  4.432072
# 70    5.477  5.374747
# 84    5.129  5.099607
# 130   4.292  4.529301
# 132   4.252  4.226362
# 59    5.791  5.889557
# 17    6.940  6.964289
# 156   2.905  3.184786
# 68    5.589  5.558229
# 110   4.681  4.702795
# 52    5.878  5.905063
# 104   4.788  4.734916
# 151   3.587  3.593007
# 99    4.874  4.895680
# 145   3.781  3.746264
# 101   4.857  4.748515
# 16    6.946  6.962955
# 82    5.192  5.204583
# 136   4.033  4.029458
# 23    6.798  6.755307
# 10    7.278  7.335318
# 108   4.694  4.743943
# <AxesSubplot:>
