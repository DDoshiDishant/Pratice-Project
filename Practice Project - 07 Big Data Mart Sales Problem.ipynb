# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('bigdata_train.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df1=pd.read_csv('bigdata_test.csv')
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# This show that Low Fat ,LF and low fat showing same value and reg and Regular showing same thing so we will replace them in any one.

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace('LF','Low Fat')

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace('low fat','Low Fat')

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace('reg','Regular')

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df1['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
df1['Item_Fat_Content']=df1['Item_Fat_Content'].replace('LF','Low Fat')

# %%
df1['Item_Fat_Content']=df1['Item_Fat_Content'].replace('low fat','Low Fat')

# %%
df1['Item_Fat_Content']=df1['Item_Fat_Content'].replace('reg','Regular')

# %%
df1['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCF42     9
# NCL31     9
# FDX04     9
#          ..
# FDE52     1
# DRF48     1
# FDN52     1
# FDC23     1
# FDY43     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df1['Item_Identifier'].value_counts()
# Out:
# FDZ50    8
# FDK57    8
# FDP15    8
# FDN52    8
# NCS41    8
#         ..
# FDY55    1
# FDC16    1
# NCQ53    1
# FDI57    1
# FDV60    1
# Name: Item_Identifier, Length: 1543, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
df1['Item_Type'].value_counts()
# Out:
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: Item_Type, dtype: int64

# %% [markdown]
# There are 16 type of Items and later we will convert it into the category for batter modeling.

# %% [markdown]
# # Missing Values

# %%
missing_features=[features for features in df.columns if df[features].isnull().sum()>1]
missing_features
# Out:
# ['Item_Weight', 'Outlet_Size']

# %%
for feature in missing_features:
    print(feature,np.round(df[feature].isnull().mean(),4),'% missing values')
# Out:
# Item_Weight 0.1717 % missing values
# Outlet_Size 0.2828 % missing values

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# There are some data is null in datasets that we will fill with mean and most frequent.

# %%
missing_features=[features for features in df1.columns if df1[features].isnull().sum()>1]
missing_features
# Out:
# ['Item_Weight', 'Outlet_Size']

# %%
for feature in missing_features:
    print(feature,np.round(df1[feature].isnull().mean(),4),'% missing values')
# Out:
# Item_Weight 0.1718 % missing values
# Outlet_Size 0.2827 % missing values

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No Duplicate data is present in dataset.

# %% [markdown]
# # Differentiate in Numeric & Categorical Features

# %%
numeric_features=[features for features in df.columns if df[features].dtype!='O']
print('Number Of Numeric Features=',len(numeric_features))
numeric_features
# Out:
# Number Of Numeric Features= 5
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales']

# %%
categorical_features=[features for features in df.columns if df[features].dtype=='O']
print('Number Of Categorical Features=',len(categorical_features))
categorical_features
# Out:
# Number Of Categorical Features= 7
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
year_features=[features for features in numeric_features if 'Year' in features]
year_features
# Out:
# ['Outlet_Establishment_Year']

# %%
discrete_features=[features for features in numeric_features if len(df[features].unique())<25 and features not in year_features]
discrete_features
# Out:
# []

# %% [markdown]
# No discrete features are in dataset

# %%
continues_features=[features for features in numeric_features if features not in discrete_features+year_features]
print('Number of continues_features=',len(continues_features))
continues_features
# Out:
# Number of continues_features= 4
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']

# %% [markdown]
# Test Dataset

# %%
numeric_features1=[features for features in df1.columns if df1[features].dtype!='O']
print('Number Of Numeric Features=',len(numeric_features))
numeric_features1
# Out:
# Number Of Numeric Features= 5
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']

# %%
categorical_features1=[features for features in df1.columns if df1[features].dtype=='O']
print('Number Of Categorical Features=',len(categorical_features1))
categorical_features1
# Out:
# Number Of Categorical Features= 7
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
year_features1=[features for features in numeric_features1 if 'Year' in features]
year_features1
# Out:
# ['Outlet_Establishment_Year']

# %%
continues_features1=[features for features in numeric_features1 if features not in year_features1]
print('Number of continues_features=',len(continues_features1))
continues_features1
# Out:
# Number of continues_features= 3
# ['Item_Weight', 'Item_Visibility', 'Item_MRP']

# %% [markdown]
# # Visuallization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Train

# %%
for i in continues_features:
    plt.figure()
    sns.distplot(df[i],color='green')

# %% [markdown]
# From Above chart there is no any pattern in Item_MRP & Item_Weight and Item_Outlet_Sales & Item_Visibility having rightskew.

# %% [markdown]
# Test

# %%
for i in continues_features1:
    plt.figure()
    sns.distplot(df1[i],color='purple')

# %% [markdown]
# Train

# %%
for i in continues_features:
    plt.figure()
    sns.scatterplot(x=i,y='Item_Outlet_Sales',data=df,color='green')

# %% [markdown]
# from this chart we conclude that:
#
#     Item Weight=12.5 having max sales.
#     visibility around 0.20 & more sales are very low.
#     as the MRP increses sales also increases.

# %% [markdown]
# Train

# %%
for i in continues_features:
    plt.figure()
    sns.boxplot(df[i],color='green')

# %% [markdown]
# Some Outliers are present in Dataset.

# %% [markdown]
# Test

# %%
for i in continues_features1:
    plt.figure()
    sns.boxplot(df1[i],color='purple')

# %%
for i in categorical_features[1:]:
    plt.figure()
    df[i].value_counts().plot(kind='bar',label='index',color=['yellow','red','green','orange','blue','black','violet','purple'])
    plt.xlabel(i)

# %% [markdown]
# We Conclude From This Chart:
#
# Low fat having high sales volume
#
# Fruits and Vegetables have high sales volume and Sea food having less sales volume
#
# most of Mart having medium size.
#
# Most outlet are in Tier-03 city and tier-01 having less outlet
#
# Most of the mart are supermarket type1.

# %% [markdown]
# Test

# %%
for i in categorical_features1[1:]:
    plt.figure()
    df1[i].value_counts().plot(kind='bar',label='index',color=['yellow','red','green','orange','blue','black','violet','purple'])
    plt.xlabel(i)

# %% [markdown]
# Train

# %%
plt.figure(figsize=(22,5))
sns.stripplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(22,5))
sns.stripplot(x='Item_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.stripplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.stripplot(x='Outlet_Size',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.stripplot(x='Outlet_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.stripplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Mart Location in Tire-03 having high sales.

# %% [markdown]
# Medium Outlate size having high sales.

# %% [markdown]
# Store Supermarket type3 having high sales.

# %% [markdown]
# # Handling With Missing Values

# %% [markdown]
# Train

# %%
from sklearn.impute import SimpleImputer

# %%
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
imp=SimpleImputer(strategy='most_frequent')
df['Outlet_Size']=imp.fit_transform(df['Outlet_Size'].values.reshape(-1,1))

# %% [markdown]
# We creat new feature from Item_Identifier for easy understanding and making 03 categoery.

# %%
df['Item_Identifier_Join']=df['Item_Identifier'].apply(lambda x:x[0:2])
df['Item_Identifier_Join']=df['Item_Identifier_Join'].map({'FD':'Food','NC':'Non-Consumable','DR':'Drinks'})
df['Item_Identifier_Join'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: Item_Identifier_Join, dtype: int64

# %% [markdown]
# we creat new feature on basis on outlet establishment year into the Outlet_Age for better understanding with salesdata.

# %%
df['Outlet_Age']=[2013]-df['Outlet_Establishment_Year']
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# Test

# %%
df1['Item_Weight']=df1['Item_Weight'].fillna(df1['Item_Weight'].mean())

# %%
imp=SimpleImputer(strategy='most_frequent')
df1['Outlet_Size']=imp.fit_transform(df1['Outlet_Size'].values.reshape(-1,1))

# %% [markdown]
# We creat new feature from Item_Identifier for easy understanding and making 03 categoery.

# %%
df1['Item_Identifier_Join']=df1['Item_Identifier'].apply(lambda x:x[0:2])
df1['Item_Identifier_Join']=df1['Item_Identifier_Join'].map({'FD':'Food','NC':'Non-Consumable','DR':'Drinks'})
df1['Item_Identifier_Join'].value_counts()
# Out:
# Food              4076
# Non-Consumable    1087
# Drinks             518
# Name: Item_Identifier_Join, dtype: int64

# %% [markdown]
# we creat new feature on basis on outlet establishment year into the Outlet_Age for better understanding with salesdata.

# %%
df1['Outlet_Age']=[2013]-df1['Outlet_Establishment_Year']
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000          Regular         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type Item_Identifier_Join  Outlet_Age
# ...

# %% [markdown]
# # Encoding

# %% [markdown]
# Train

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Item_Identifier_Join','Outlet_Type']

# %%
lb=LabelEncoder()

# %%
for i in l:
    df[i]=lb.fit_transform(df[i])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 1         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 1         0.000000          6
# 4           NCD19         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            1
# 4   53.8614                  1                       1987            0
#
# ...

# %% [markdown]
# Test

# %%
for i in l:
    df1[i]=lb.fit_transform(df1[i])
    
df1.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58    20.750000                 0         0.007565         13
# 1           FDW14     8.300000                 1         0.038428          4
# 2           NCN55    14.600000                 0         0.099575         11
# 3           FDQ58     7.315000                 0         0.015388         13
# 4           FDY38    12.695633                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            1
# 2  241.7538                  0                       1998            1
# 3  155.0340                  2                       2007            1
# 4  234.2300                  5                       1985            1
#
#    Outlet_Location_Type  Outlet_Type  Item_Identifier_Join  Outlet_Age
# ...

# %%
df.drop(['Item_Identifier','Outlet_Establishment_Year'],axis=1,inplace=True)

# %%
df1.drop(['Item_Identifier','Outlet_Establishment_Year'],axis=1,inplace=True)

# %% [markdown]
# # Statastical

# %% [markdown]
# Train

# %%
df.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857645          0.352693         0.066132     7.226681
# std       4.226124          0.477836         0.051598     4.209990
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.310000          0.000000         0.026989     4.000000
# 50%      12.857645          0.000000         0.053931     6.000000
# 75%      16.000000          1.000000         0.094585    10.000000
# max      21.350000          1.000000         0.328391    15.000000
#
#           Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Location_Type  \
# count  8523.000000        8523.000000  8523.000000           8523.000000
# mean    140.992782           4.722281     1.170832              1.112871
# std      62.275067           2.837201     0.600327              0.812757
# ...

# %% [markdown]
# From this Statastical we can see that Item Visiblity having minimum value=0.00 that can not possible because as the item is present in mall than how it can be zero.
# and Outlate establishment year in range between 1985-2009

# %% [markdown]
# Test

# %%
df1.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# count  5681.000000       5681.000000      5681.000000  5681.000000
# mean     12.695633          0.354339         0.065684     7.233410
# std       4.245189          0.478355         0.051252     4.219057
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.195000          0.000000         0.027047     4.000000
# 50%      12.695633          0.000000         0.054154     6.000000
# 75%      15.850000          1.000000         0.093463    10.000000
# max      21.350000          1.000000         0.323637    15.000000
#
#           Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Location_Type  \
# count  5681.000000        5681.000000  5681.000000           5681.000000
# mean    141.023273           4.722760     1.170921              1.112832
# std      61.809091           2.837201     0.600328              0.812824
# ...

# %%
corr=df.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this Corelation chart we can say that Item_MRP and Outlet_Type are much coreleated with Outletsales.

# %% [markdown]
# # Data Cleaning

# %%
df.skew()
# Out:
# Item_Weight             0.090561
# Item_Fat_Content        0.616705
# Item_Visibility         1.167091
# Item_Type               0.101655
# Item_MRP                0.127202
# Outlet_Identifier      -0.059861
# Outlet_Size            -0.087072
# Outlet_Location_Type   -0.209093
# Outlet_Type             0.927438
# Item_Outlet_Sales       1.177531
# Item_Identifier_Join    0.114510
# Outlet_Age              0.396641
# dtype: float64

# %% [markdown]
# Outliers Removing

# %%
df.shape
# Out:
# (8523, 12)

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
thershold=3
print(np.where(z>3))
df_new=df[(z<3).all(axis=1)]
# Out:
# (array([  49,   83,  108,  130,  145,  174,  276,  304,  333,  373,  434,
#         456,  472,  502,  521,  532,  661,  694,  753,  809,  854,  935,
#         991,  997, 1009, 1138, 1159, 1254, 1272, 1291, 1311, 1324, 1434,
#        1450, 1496, 1501, 1506, 1560, 1575, 1644, 1651, 1805, 1827, 1841,
#        1859, 1998, 2088, 2109, 2122, 2216, 2238, 2251, 2293, 2324, 2439,
#        2445, 2516, 2535, 2586, 2613, 2728, 2776, 2855, 2895, 3017, 3083,
#        3087, 3098, 3154, 3206, 3234, 3286, 3399, 3407, 3458, 3474, 3488,
#        3497, 3540, 3667, 3709, 3720, 3750, 3757, 3767, 3884, 3993, 4006,
#        4219, 4289, 4346, 4349, 4382, 4408, 4530, 4656, 4674, 4676, 4681,
#        4772, 4789, 4888, 4941, 4961, 4991, 5031, 5065, 5150, 5177, 5185,
#        5223, 5287, 5315, 5374, 5500, 5550, 5619, 5732, 5734, 5752, 5795,
#        5799, 5812, 5837, 5880, 5891, 5946, 5977, 6000, 6008, 6012, 6134,
#        6179, 6334, 6409, 6536, 6537, 6541, 6576, 6606, 6622, 6674, 6786,
# ...

# %%
df_new.shape
# Out:
# (8338, 12)

# %%
dataloss=(8523-8338)/8523*100
dataloss
# Out:
# 2.170597207556025

# %%
df=df_new

# %% [markdown]
# Test

# %%
df1.shape
# Out:
# (5681, 11)

# %%
z=np.abs(zscore(df1))
thershold=3
print(np.where(z>3))
df1_new=df1[(z<3).all(axis=1)]
df1_new.shape
# Out:
# (array([  46,   76,   78,   89,  138,  333,  385,  474,  543,  637,  858,
#         871, 1046, 1191, 1256, 1270, 1411, 1516, 1547, 1577, 1616, 1710,
#        1812, 1823, 1857, 1915, 1919, 2019, 2179, 2230, 2365, 2380, 2393,
#        2504, 2516, 2561, 2605, 2609, 2625, 2628, 2677, 2779, 2836, 2843,
#        3267, 3294, 3313, 3316, 3346, 3378, 3502, 3638, 3679, 3970, 4052,
#        4147, 4159, 4208, 4255, 4328, 4365, 4421, 4575, 4616, 4689, 4801,
#        4804, 4846, 4919, 4976, 4999, 5121, 5157, 5277, 5290, 5435, 5469,
#        5482, 5514, 5571, 5668], dtype=int64), array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64))
# (5600, 11)

# %%
dataloss=(5681-5600)/5681*100
dataloss
# Out:
# 1.425805315965499

# %%
df1=df1_new

# %% [markdown]
# Skewness Removing

# %% [markdown]
# Train

# %%
df.skew()
# Out:
# Item_Weight             0.089291
# Item_Fat_Content        0.620973
# Item_Visibility         0.794272
# Item_Type               0.098295
# Item_MRP                0.138990
# Outlet_Identifier      -0.065135
# Outlet_Size            -0.087933
# Outlet_Location_Type   -0.202674
# Outlet_Type             0.956727
# Item_Outlet_Sales       0.878267
# Item_Identifier_Join    0.111869
# Outlet_Age              0.423379
# dtype: float64

# %% [markdown]
# Skewness Removing

# %% [markdown]
# skew standard -0.5 to +0.5 so Item_Visibility and Item_Outlet_Sales having skewness.

# %%
df['Item_Visibility']=np.sqrt(df['Item_Visibility'])
df['Item_Outlet_Sales']=np.sqrt(df['Item_Outlet_Sales'])

# %% [markdown]
# Test

# %%
df1.skew()
# Out:
# Item_Weight             0.140901
# Item_Fat_Content        0.616007
# Item_Visibility         0.787861
# Item_Type               0.091394
# Item_MRP                0.133061
# Outlet_Identifier      -0.069734
# Outlet_Size            -0.082542
# Outlet_Location_Type   -0.212992
# Outlet_Type             0.953152
# Item_Identifier_Join    0.119481
# Outlet_Age              0.411451
# dtype: float64

# %%
df1['Item_Visibility']=np.sqrt(df1['Item_Visibility'])

# %%
x=df.drop('Item_Outlet_Sales',axis=1)

# %%
x.shape
# Out:
# (8338, 11)

# %%
y=df['Item_Outlet_Sales']

# %% [markdown]
# StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
X=std.fit_transform(x)

# %%
x=X
x
# Out:
# array([[-0.8371775 , -0.73664489, -1.0017811 , ..., -0.25983859,
#         -0.18252049, -0.12054907],
#        [-1.63203555,  1.35750619, -0.88454741, ...,  1.02213428,
#         -2.09200079, -1.32272361],
#        [ 1.09117635, -0.73664489, -0.97497045, ..., -0.25983859,
#         -0.18252049, -0.12054907],
#        ...,
#        [-0.53146287, -0.73664489, -0.41501791, ..., -0.25983859,
#          1.72695982, -0.72163634],
#        [-1.32867257,  1.35750619,  1.44924692, ...,  1.02213428,
#         -0.18252049, -1.32272361],
#        [ 0.45623057, -0.73664489, -0.18123692, ..., -0.25983859,
#         -2.09200079,  0.11988584]])

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
ln=LinearRegression()

# %%
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    ln=LinearRegression()
    ln.fit(x_train,y_train)
    predtest=ln.predict(x_test)
    predtrain=ln.predict(x_train)
    if round(r2_score(y_train,predtrain)*100,2)==round(r2_score(y_test,predtest)*100,2):
        print('At random state',i,'score is best')
        print('Train score',r2_score(y_train,predtrain)*100)
        print('Test Score',r2_score(y_test,predtest)*100)
# Out:
# At random state 268 score is best
# Train score 55.21363284954972
# Test Score 55.206463803502984
# At random state 282 score is best
# Train score 55.19722367769968
# Test Score 55.19804607486998
# At random state 371 score is best
# Train score 55.201393925698724
# Test Score 55.20401005954989

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=268)

# %%
ln=LinearRegression()
ln.fit(x_train,y_train)
pred=ln.predict(x_test)
print('Train Score',ln.score(x_train,y_train)*100)
# Out:
# Train Score 55.21363284954972

# %%
print('Error')
print('Mean Absoluate Error',mean_absolute_error(y_test,pred))
print('Mean Squared Error',mean_squared_error(y_test,pred))
print('Room Mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
print('R2 Score',r2_score(y_test,pred)*100)
# Out:
# Error
# Mean Absoluate Error 9.465039871770456
# Mean Squared Error 138.63620018047177
# Room Mean Squared Error 11.774387465192055
# R2 Score 55.206463803502984

# %% [markdown]
# Using Different Regressior Model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
dtc=DecisionTreeRegressor()
svm=SVR()
svmp=SVR(kernel='poly')
svml=SVR(kernel='linear')
kn=KNeighborsRegressor()

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Taining Score:-',f.score(x_train,y_train)*100)
    print('Mean Absolute Error',mean_absolute_error(y_test,pred))
    print('Mean Squared Error',mean_squared_error(y_test,pred))
    print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,pred)))
    print('R2 Score',r2_score(y_test,pred)*100)

# %%
fun(dtc)
# Out:
# Taining Score:- 100.0
# Mean Absolute Error 11.408539618013629
# Mean Squared Error 220.84717566604664
# Root Mean Squared Erro 14.860927819824933
# R2 Score 28.643990933007046

# %%
fun(svm)
# Out:
# Taining Score:- 65.6379739158679
# Mean Absolute Error 8.20759419459527
# Mean Squared Error 109.34449229643347
# Root Mean Squared Erro 10.456791682750186
# R2 Score 64.67065263479573

# %%
fun(svmp)
# Out:
# Taining Score:- 62.91978772911371
# Mean Absolute Error 8.511452566777603
# Mean Squared Error 117.27241755691524
# Root Mean Squared Erro 10.829239010979268
# R2 Score 62.1091296944942

# %%
fun(svml)
# Out:
# Taining Score:- 55.06901235512507
# Mean Absolute Error 9.459304391495891
# Mean Squared Error 139.08391581654996
# Root Mean Squared Erro 11.793384408919687
# R2 Score 55.06180630045328

# %%
fun(kn)
# Out:
# Taining Score:- 72.58979078656391
# Mean Absolute Error 8.965142489134525
# Mean Squared Error 132.31812201970646
# Root Mean Squared Erro 11.502961445632446
# R2 Score 57.24784305667154

# %% [markdown]
# # Ensemble Method

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rdf=RandomForestRegressor()
ad=AdaBoostRegressor()
gd=GradientBoostingRegressor()

# %%
fun(rdf)
# Out:
# Taining Score:- 94.71329746481028
# Mean Absolute Error 8.221665939110437
# Mean Squared Error 114.84179257209439
# Root Mean Squared Erro 10.716426296676257
# R2 Score 62.89446778148701

# %%
fun(ad)
# Out:
# Taining Score:- 64.21881803439116
# Mean Absolute Error 8.2787362689875
# Mean Squared Error 111.67243527980744
# Root Mean Squared Erro 10.56751793373484
# R2 Score 63.91849123572826

# %%
fun(gd)
# Out:
# Taining Score:- 68.8443045647005
# Mean Absolute Error 7.838512594026864
# Mean Squared Error 104.1247040849948
# Root Mean Squared Erro 10.204151316253341
# R2 Score 66.35717298000685

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
ls=Lasso()
rd=Ridge()
es=ElasticNet()

# %%
fun(ls)
# Out:
# Taining Score:- 52.45207581762703
# Mean Absolute Error 9.865452142252117
# Mean Squared Error 148.0804497764686
# Root Mean Squared Erro 12.16883107683185
# R2 Score 52.155014502553186

# %%
fun(rd)
# Out:
# Taining Score:- 55.213630184775454
# Mean Absolute Error 9.4651558530292
# Mean Squared Error 138.6373576924415
# Root Mean Squared Erro 11.774436618897802
# R2 Score 55.20608980988337

# %%
fun(es)
# Out:
# Taining Score:- 46.43857789716025
# Mean Absolute Error 10.661281896395952
# Mean Squared Error 166.5061304487882
# Root Mean Squared Erro 12.903725448442717
# R2 Score 46.20165316499323

# %% [markdown]
# # Hyper Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'max_features':['auto','sqrt','log2'],
          'max_depth':[4,5,6,7,8]
           }

# %%
gd1=GridSearchCV(rdf,parameter)

# %%
gd1.fit(x,y)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
print(gd1.best_score_)
print(gd1.best_params_)
# Out:
# 0.6595012922170203
# {'max_depth': 6, 'max_features': 'auto'}

# %%
rdf1=RandomForestRegressor(max_depth=6,max_features='auto')

# %%
rdf1.fit(x_train,y_train)
predrdf1=rdf1.predict(x_test)
print('Taining Score:-',rdf1.score(x_train,y_train)*100)
print('Mean Absolute Error',mean_absolute_error(y_test,predrdf1))
print('Mean Squared Error',mean_squared_error(y_test,predrdf1))
print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,predrdf1)))
print('R2 Score',r2_score(y_test,predrdf1)*100)
# Out:
# Taining Score:- 67.93254487535772
# Mean Absolute Error 7.856427756458735
# Mean Squared Error 104.26980744316357
# Root Mean Squared Erro 10.21125885692668
# R2 Score 66.31028989667143

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,20):
    crs_score=cross_val_score(ln,x_train,y_train,cv=i)
    score=crs_score.mean()
    print('cv value:',i)
    print('cross value score:',score*100)
    print('actual score:',r2_score(y_test,pred)*100)
# Out:
# cv value: 2
# cross value score: 54.91009892149875
# actual score: 55.206463803502984
# cv value: 3
# cross value score: 54.96899710237847
# actual score: 55.206463803502984
# cv value: 4
# cross value score: 54.97621959971553
# actual score: 55.206463803502984
# cv value: 5
# cross value score: 54.954105790365794
# actual score: 55.206463803502984
# cv value: 6
# cross value score: 54.97895460979413
# actual score: 55.206463803502984
# cv value: 7
# cross value score: 54.94265487598098
# actual score: 55.206463803502984
# cv value: 8
# cross value score: 54.9151721537136
# actual score: 55.206463803502984
# cv value: 9
# cross value score: 54.962252577709904
# actual score: 55.206463803502984
# cv value: 10
# cross value score: 54.925672638760425
# actual score: 55.206463803502984
# cv value: 11
# cross value score: 54.99207419710511
# actual score: 55.206463803502984
# cv value: 12
# cross value score: 54.94841503887048
# actual score: 55.206463803502984
# cv value: 13
# ...

# %%
crs_score=cross_val_score(dtc,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 30.562947354234993

# %%
crs_score=cross_val_score(svm,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 64.33228436720476

# %%
crs_score=cross_val_score(svmp,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 61.27804852822618

# %%
crs_score=cross_val_score(svml,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 54.82314542240153

# %%
crs_score=cross_val_score(kn,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 58.3361643293999

# %%
crs_score=cross_val_score(rdf1,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 66.01262038836275

# %%
crs_score=cross_val_score(ad,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 63.44444280809021

# %%
crs_score=cross_val_score(gd,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 66.0702490182052

# %%
crs_score=cross_val_score(ls,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 52.35639249026058

# %%
crs_score=cross_val_score(rd,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 54.9921460959431

# %%
crs_score=cross_val_score(es,x_train,y_train,cv=11)
score=crs_score.mean()
print(score*100)
# Out:
# 46.328784043671284

# %%
Res=pd.DataFrame()

# %%
Res['Model']=['ln','svm','svmp','svml','kn','rdf1','ad','gd','ls','rd','es','dtc']

# %%
Res['R2_Score']=[55.20,64.67,62.10,55.06,57.24,66.41,64.23,66.56,52.12,55.20,46.20,30.37]
Res['CV_Score']=[54.99,64.33,61.27,54.82,58.33,66.03,63.71,66.06,52.35,54.99,46.32,30.08]
Res['Differance']=Res['R2_Score']-Res['CV_Score']
Res['RMSE']=[11.77,10.45,10.82,11.79,11.50,10.19,10.52,10.20,12.16,11.77,12.90,10.45]
Res
# Out:
#    Model  R2_Score  CV_Score  Differance   RMSE
# 0     ln     55.20     54.99        0.21  11.77
# 1    svm     64.67     64.33        0.34  10.45
# 2   svmp     62.10     61.27        0.83  10.82
# 3   svml     55.06     54.82        0.24  11.79
# 4     kn     57.24     58.33       -1.09  11.50
# 5   rdf1     66.41     66.03        0.38  10.19
# 6     ad     64.23     63.71        0.52  10.52
# 7     gd     66.56     66.06        0.50  10.20
# 8     ls     52.12     52.35       -0.23  12.16
# 9     rd     55.20     54.99        0.21  11.77
# 10    es     46.20     46.32       -0.12  12.90
# 11   dtc     30.37     30.08        0.29  10.45

# %% [markdown]
# # Saving Model

# %%
import pickle
filename='Big Data Mart Sales Prediction.pkl'
pickle.dump(rdf1,open(filename,'wb'))

# %%
rs=pd.DataFrame()
rs['Actual']=y_test
rs['Predict']=predrdf1

rs

print(rs)
sns.regplot(y_test,predrdf1)
plt.title('Regressor Line')
# Out:
#          Actual    Predict
# 4565  40.814600  54.154881
# 4293  20.626347  27.482182
# 2000  34.781584  29.112822
# 4909  11.276870  15.548117
# 1911  23.984395  26.603308
# ...         ...        ...
# 8141  21.277782  27.548888
# 815   26.852586  24.644600
# 5239  44.137635  39.097923
# 1774  61.539178  60.504943
# 4161  38.001582  49.689442
#
# [1668 rows x 2 columns]
# Text(0.5, 1.0, 'Regressor Line')
